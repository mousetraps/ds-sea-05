# %%
## from numpy import * #Load all the numpy packages
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
path = '../SQL/'
data = pd.read_csv('ABC_exposure_durations.csv')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-87fd4a28bb21> in <module>()
#       1 path = '../SQL/'
# ----> 2 data = pd.read_csv('ABC_exposure_durations.csv')
#
# ...
